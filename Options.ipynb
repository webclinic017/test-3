# %%
import yfinance as yf
import numpy as np
import pandas as pd

payload=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
first_table = payload[0]
second_table = payload[1]
#print(first_table.head())
sip=np.array(first_table.iloc[:,0])
df=pd.DataFrame()
for i in range(0,len(sip)):

    ticker=sip[i]
    start_date="1970-01-01"
    end_date="2021-10-01"
    intr="1wk"
    data = yf.download(ticker, start_date, end_date,interval=intr)
    data["ChangeP"]=(data.Close-data.Open)/data.Open
    STD=np.std(data.ChangeP)
    #dict=dict.append({"tick":1,"STD%":2})
    temp=pd.Series([ticker,STD])
    df=df.append(temp,ignore_index=True)



    #print(data.head())
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df.to_csv('spy_std.csv')

# %%
import yfinance as yf
apple= yf.Ticker("aapl")
apple.option_chain(date='2021-10-22').calls
# Out:
#          contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0   AAPL211022C00075000 2021-10-19 15:18:50    75.0      73.55  73.50  73.60
# 1   AAPL211022C00080000 2021-10-19 17:55:48    80.0      68.80  68.55  68.65
# 2   AAPL211022C00085000 2021-10-18 13:35:03    85.0      58.45  63.50  63.60
# 3   AAPL211022C00090000 2021-10-19 19:21:38    90.0      58.65  58.55  58.60
# 4   AAPL211022C00095000 2021-10-18 15:05:03    95.0      50.10  53.55  53.70
# 5   AAPL211022C00100000 2021-10-19 14:46:37   100.0      48.55  48.55  48.65
# 6   AAPL211022C00105000 2021-10-19 17:57:45   105.0      43.90  43.55  43.65
# 7   AAPL211022C00110000 2021-10-19 15:19:15   110.0      38.55  38.55  38.65
# 8   AAPL211022C00115000 2021-10-19 15:45:57   115.0      33.55  33.55  33.65
# 9   AAPL211022C00117000 2021-10-13 13:52:08   117.0      22.85  31.55  31.70
# 10  AAPL211022C00118000 2021-10-13 22:27:43   118.0      21.85  30.50  30.65
# ...
