# %%
import yfinance as yf
from datetime import datetime
#from datetime import date
#import datetime
import pandas as pd
import numpy as np 

start=(datetime.now())

payload=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
sip=np.array(payload.iloc[0:5,0])

df_earn=pd.DataFrame()
earn = [(pd.Timestamp(yf.Ticker(sip[i]).calendar.iloc[0,0])) for i in range (0, len(sip))]

finish = datetime.now()
print('Duration: {}'.format(finish - start))

print(earn)
# Out:
# Duration: 0:00:14.864139
# [Timestamp('2022-01-24 13:30:00'), Timestamp('2022-01-25 13:30:00'), Timestamp('2022-02-01 13:30:00'), Timestamp('2022-01-26 13:30:00'), Timestamp('2021-12-16 13:30:00')]

# %%
import yfinance as yf
from datetime import datetime
#from datetime import date
#import datetime
import pandas as pd
import numpy as np 

start=(datetime.now())
payload=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

sip=np.array(payload.iloc[0:5,0])
df_earn=pd.DataFrame()
for i in range(0,len(sip)):
    tick= yf.Ticker(sip[i])
    try:
        earns=pd.Timestamp(tick.calendar.iloc[0,0])
    except:
        earns='failed'        
    temp=pd.Series([earns])
    df_earn=df_earn.append(temp,ignore_index=True)

finish = datetime.now()
print('Duration: {}'.format(finish - start))
print(df_earn)
# Out:
# Duration: 0:00:14.459959
#                     0
# 0 2022-01-24 13:30:00
# 1 2022-01-25 13:30:00
# 2 2022-02-01 13:30:00
# 3 2022-01-26 13:30:00
# 4 2021-12-16 13:30:00
