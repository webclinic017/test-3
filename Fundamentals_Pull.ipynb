# %%
import yfinance as yf
import pandas as pd
import numpy as np
import time
sip500=np.array(pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0].iloc[:,0])
#sip400=np.array(pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_400_companies')[0].iloc[:,1])
#sip600=np.array(pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_600_companies')[1].iloc[:,1])
#payload=np.append(sip500,sip400)
#payload=np.append(payload,sip600)
payload=sip500
arr=np.array([])
for i in range(201,300):
    try:
        ticker = yf.Ticker(payload[i])
        df=pd.DataFrame.from_dict((ticker.info),orient="index")
        arrt=np.array([payload[i],df.loc['sector'][0],df.loc['quickRatio'][0],df.loc['pegRatio'][0],df.loc['forwardPE'][0],df.loc['priceToBook'][0],df.loc['heldPercentInsiders'][0],df.loc['dividendYield'][0],df.loc['industry'][0],df.loc['targetLowPrice'][0],df.loc['currentPrice'][0]])
        arr=np.append(arr,arrt)
        print(i)
    except:
        print("pass")
        pass
        
df=pd.DataFrame(data=arr.reshape(i+1,len(arrt)))
df.columns=['stock','sector','quick_ratio','peg_ratio','PE','PtB','Insider%','dividend%','Industry','TargetLow','CurrentPrice']
df.to_csv('fundamentals.csv')
print(df)
#time.sleep(60000)
# Out:
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_60/2364914398.py in <module>
#      21         pass
#      22
# ---> 23 df=pd.DataFrame(data=arr.reshape(i+1,len(arrt)))
# ...

# %%
import yfinance as yf
import pandas as pd
ticker = yf.Ticker("MMM")
df=pd.DataFrame.from_dict((ticker.info),orient="index")
print(df.loc['zip'][0])
# Out:
# 55144-1000

# %%
df=pd.DataFrame(data=arr.reshape(99,len(arrt)))
df.columns=['stock','sector','quick_ratio','peg_ratio','PE','PtB','Insider%','dividend%','industry','target_low','current']
df.to_csv('fundamentals.csv')
print(df)
# Out:
#    stock              sector quick_ratio peg_ratio          PE        PtB  \
# 0    FLT          Technology       0.832      1.05   15.469588   6.049051
# 1    FMC     Basic Materials       0.831      2.22    16.40182   5.273875
# 2      F   Consumer Cyclical       1.031      0.16    8.331658  1.8106368
# 3   FTNT          Technology       1.696       4.9     64.5423   43.48093
# 4    FTV          Technology       0.471      0.69   19.344156  2.2929497
# ..   ...                 ...         ...       ...         ...        ...
# 94   LYB     Basic Materials       0.927      0.11   6.6298485  2.8510842
# 95   MTB  Financial Services        None       0.9   15.598453   1.479666
# 96   MRO              Energy       0.927     -5.52  11.0153055  1.5778704
# 97   MPC              Energy        None      0.89   17.739338   1.646505
# 98  MKTX  Financial Services       5.712      11.8   44.918884  12.770611
#
#         Insider%     dividend%                            industry target_low  \
# ...
